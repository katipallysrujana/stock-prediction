# %% [markdown]
# # Step-1: Importing required important libraries and loading dataset...

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ushap\anaconda3\lib\site-packages (1.4.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ushap\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ushap\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ushap\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ushap\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tataglobal_df = pd.read_csv(r"C:\Users\ushap\Downloads\NSE-TATAGLOBAL11.csv")
tataglobal_df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...                    ...              ...
# 1230             1281419.0          2039.09
# 1231             1880046.0          3030.76
# 1232             3124853.0          4978.80
# 1233             2049580.0          3204.49
# 1234             1720413.0          2688.94
#
# [1235 rows x 8 columns]

# %%
tataglobal_df.shape
# Out:
# (1235, 8)

# %%
tataglobal_df.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity    float64
# Turnover (Lacs)         float64
# dtype: object

# %%
tataglobal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
tataglobal_df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %%
tataglobal_df.isna().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
tataglobal_df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
tataglobal_df.Close.hist();

# %% [markdown]
# Parsing Dates
# When we work with time series data, we want to enrich the time & date component as much as possible
#
# We can do that by telling pandas which our column has dates in it using the parse_dates parameters

# %%
# Imoporting data again but this time parse dates

df = pd.read_csv(r"C:\Users\ushap\Downloads\NSE-TATAGLOBAL11.csv", 
                 parse_dates=["Date"])
df.head()
# Out:
#         Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0 2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1 2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2 2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3 2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4 2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
tataglobal_df.Date.dtype
# Out:
# dtype('O')

# %%
tataglobal_df.Date.head()
# Out:
# 0    2018-10-08
# 1    2018-10-05
# 2    2018-10-04
# 3    2018-10-03
# 4    2018-10-01
# Name: Date, dtype: object

# %%
df.Date.head()
# Out:
# 0   2018-10-08
# 1   2018-10-05
# 2   2018-10-04
# 3   2018-10-03
# 4   2018-10-01
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# # Step-2: Data Cleaning and Sorting by date from oldest to newest data...

# %%
df.isna().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.head()
# Out:
#         Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0 2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1 2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2 2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3 2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4 2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
df.tail()
# Out:
#            Date    Open    High     Low   Last   Close  Total Trade Quantity  \
# 1230 2013-10-14  160.85  161.45  157.70  159.3  159.45             1281419.0
# 1231 2013-10-11  161.15  163.45  159.00  159.8  160.05             1880046.0
# 1232 2013-10-10  156.00  160.80  155.85  160.3  160.15             3124853.0
# 1233 2013-10-09  155.70  158.20  154.15  155.3  155.55             2049580.0
# 1234 2013-10-08  157.00  157.80  155.20  155.8  155.80             1720413.0
#
#       Turnover (Lacs)
# 1230          2039.09
# 1231          3030.76
# 1232          4978.80
# 1233          3204.49
# 1234          2688.94

# %%
# Sort Dataframe in date order

df.sort_values(by=["Date"], inplace=True, ascending=True)
df.Date.head()
# Out:
# 1234   2013-10-08
# 1233   2013-10-09
# 1232   2013-10-10
# 1231   2013-10-11
# 1230   2013-10-14
# Name: Date, dtype: datetime64[ns]

# %%
# Let's visualize closing price vs Date... 


fig, ax = plt.subplots()
ax.scatter(df.Date, df.Close);

# %%
df
# Out:
#            Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 1234 2013-10-08  157.00  157.80  155.20  155.80  155.80             1720413.0
# 1233 2013-10-09  155.70  158.20  154.15  155.30  155.55             2049580.0
# 1232 2013-10-10  156.00  160.80  155.85  160.30  160.15             3124853.0
# 1231 2013-10-11  161.15  163.45  159.00  159.80  160.05             1880046.0
# 1230 2013-10-14  160.85  161.45  157.70  159.30  159.45             1281419.0
# ...         ...     ...     ...     ...     ...     ...                   ...
# 4    2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
# 3    2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 2    2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 1    2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 0    2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
#
#       Turnover (Lacs)
# 1234          2688.94
# 1233          3204.49
# 1232          4978.80
# 1231          3030.76
# 1230          2039.09
# ...               ...
# 4             3486.05
# 3             3960.27
# 2             3815.79
# 1             7407.06
# 0            10062.83
#
# [1235 rows x 8 columns]

# %%
copy_df = df.copy()
copy_df
# Out:
#            Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 1234 2013-10-08  157.00  157.80  155.20  155.80  155.80             1720413.0
# 1233 2013-10-09  155.70  158.20  154.15  155.30  155.55             2049580.0
# 1232 2013-10-10  156.00  160.80  155.85  160.30  160.15             3124853.0
# 1231 2013-10-11  161.15  163.45  159.00  159.80  160.05             1880046.0
# 1230 2013-10-14  160.85  161.45  157.70  159.30  159.45             1281419.0
# ...         ...     ...     ...     ...     ...     ...                   ...
# 4    2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
# 3    2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 2    2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 1    2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 0    2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
#
#       Turnover (Lacs)
# 1234          2688.94
# 1233          3204.49
# 1232          4978.80
# 1231          3030.76
# 1230          2039.09
# ...               ...
# 4             3486.05
# 3             3960.27
# 2             3815.79
# 1             7407.06
# 0            10062.83
#
# [1235 rows x 8 columns]

# %%
copy_df.reset_index(inplace =True)
copy_df
# Out:
#       index       Date    Open    High     Low    Last   Close  \
# 0      1234 2013-10-08  157.00  157.80  155.20  155.80  155.80
# 1      1233 2013-10-09  155.70  158.20  154.15  155.30  155.55
# 2      1232 2013-10-10  156.00  160.80  155.85  160.30  160.15
# 3      1231 2013-10-11  161.15  163.45  159.00  159.80  160.05
# 4      1230 2013-10-14  160.85  161.45  157.70  159.30  159.45
# ...     ...        ...     ...     ...     ...     ...     ...
# 1230      4 2018-10-01  234.55  234.60  221.05  230.30  230.90
# 1231      3 2018-10-03  230.00  237.50  225.75  226.45  227.60
# 1232      2 2018-10-04  223.50  227.80  216.15  217.25  218.20
# 1233      1 2018-10-05  217.00  218.60  205.90  210.25  209.20
# 1234      0 2018-10-08  208.00  222.25  206.85  216.00  215.15
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                1720413.0          2688.94
# 1                2049580.0          3204.49
# 2                3124853.0          4978.80
# 3                1880046.0          3030.76
# 4                1281419.0          2039.09
# ...                    ...              ...
# 1230             1534749.0          3486.05
# 1231             1708590.0          3960.27
# 1232             1728786.0          3815.79
# 1233             3519515.0          7407.06
# 1234             4642146.0         10062.83
#
# [1235 rows x 9 columns]

# %%
copy_df.drop("index", axis=1, inplace=True)
copy_df
# Out:
#            Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0    2013-10-08  157.00  157.80  155.20  155.80  155.80             1720413.0
# 1    2013-10-09  155.70  158.20  154.15  155.30  155.55             2049580.0
# 2    2013-10-10  156.00  160.80  155.85  160.30  160.15             3124853.0
# 3    2013-10-11  161.15  163.45  159.00  159.80  160.05             1880046.0
# 4    2013-10-14  160.85  161.45  157.70  159.30  159.45             1281419.0
# ...         ...     ...     ...     ...     ...     ...                   ...
# 1230 2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
# 1231 2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 1232 2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 1233 2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 1234 2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
#
#       Turnover (Lacs)
# 0             2688.94
# 1             3204.49
# 2             4978.80
# 3             3030.76
# 4             2039.09
# ...               ...
# 1230          3486.05
# 1231          3960.27
# 1232          3815.79
# 1233          7407.06
# 1234         10062.83
#
# [1235 rows x 8 columns]

# %%
# Let's see correlation matrix...
copy_df.corr()
# Out:
#                           Open      High       Low      Last     Close  \
# Open                  1.000000  0.998956  0.998776  0.997662  0.997704
# High                  0.998956  1.000000  0.998728  0.999130  0.999159
# Low                   0.998776  0.998728  1.000000  0.999008  0.999065
# Last                  0.997662  0.999130  0.999008  1.000000  0.999963
# Close                 0.997704  0.999159  0.999065  0.999963  1.000000
# Total Trade Quantity  0.367503  0.388798  0.361695  0.381269  0.380801
# Turnover (Lacs)       0.587026  0.605907  0.582446  0.599575  0.599155
#
#                       Total Trade Quantity  Turnover (Lacs)
# Open                              0.367503         0.587026
# High                              0.388798         0.605907
# Low                               0.361695         0.582446
# Last                              0.381269         0.599575
# Close                             0.380801         0.599155
# Total Trade Quantity              1.000000         0.941976
# Turnover (Lacs)                   0.941976         1.000000

# %%
plt.figure(figsize=(10,7))
plt.plot(copy_df["Date"],
         copy_df["Close"])
plt.xlabel("Date")
plt.ylabel("Closed Price");
plt.title("Variation of Closing price with different Date year",
          color="orange",
          fontsize=18);

# %% [markdown]
# # Step-3: Applying univariate approch by selecting Closing Price as target variables.
# Univariate Analysis of Closing Price

# %%
# Considering only `Close` variable...

close_df = copy_df["Close"]
close_df
# Out:
# 0       155.80
# 1       155.55
# 2       160.15
# 3       160.05
# 4       159.45
#          ...
# 1230    230.90
# 1231    227.60
# 1232    218.20
# 1233    209.20
# 1234    215.15
# Name: Close, Length: 1235, dtype: float64

# %% [markdown]
# # Step-4: Exploration and Analysis of Datasets.

# %%
close_df.size
# Out:
# 1235

# %%
close_df.shape
# Out:
# (1235,)

# %%
close_df.info
# Out:
# <bound method Series.info of 0       155.80
# 1       155.55
# 2       160.15
# 3       160.05
# 4       159.45
#          ...
# 1230    230.90
# 1231    227.60
# 1232    218.20
# 1233    209.20
# 1234    215.15
# Name: Close, Length: 1235, dtype: float64>

# %%
close_df.describe
# Out:
# <bound method NDFrame.describe of 0       155.80
# 1       155.55
# 2       160.15
# 3       160.05
# 4       159.45
#          ...
# 1230    230.90
# 1231    227.60
# 1232    218.20
# 1233    209.20
# 1234    215.15
# Name: Close, Length: 1235, dtype: float64>

# %%
plt.plot(copy_df.Date, close_df)
plt.xlabel("Time in Year")
plt.ylabel("Closing Price");
plt.title("Variation of Closing price with Time",
          color="orange",
          fontsize=18);

# %% [markdown]
# # Step-5: Preprocessing by MinMax Scaler.
# LSTM is very sensitive to small change in value and so to the scale of the data. Thus, using MinMax Scaler, we scale it in the range of [0,1]

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler(feature_range=(0,1)) # (0,1) by default.But mentioned for understanding
close_df = minmax.fit_transform(np.array(close_df).reshape(-1, 1))
close_df
# Out:
# array([[0.23823398],
#        [0.2371134 ],
#        [0.25773196],
#        ...,
#        [0.51792918],
#        [0.47758853],
#        [0.50425818]])

# %% [markdown]
# # Step-6: Preparing train and test datasets.

# %%
train_size = int(len(close_df)*0.7)
test_size = len(close_df) - train_size
train_data = close_df[:train_size, :] # Slicing row from 0 to train_size indexlocation but column is kept unsliced.
test_data = close_df[train_size:len(close_df), :1]

# %%
train_data.shape
# Out:
# (864, 1)

# %%
test_data.shape
# Out:
# (371, 1)

# %%
864+371
# Out:
# 1235

# %%
test_data[:10]
# Out:
# array([[0.22747647],
#        [0.22008068],
#        [0.21447781],
#        [0.2097714 ],
#        [0.20394442],
#        [0.21313312],
#        [0.2218736 ],
#        [0.21806365],
#        [0.22097714],
#        [0.21985657]])

# %% [markdown]
# Preparing our dataset for training, fitting and testing of LSTM model

# %%
#This function will create dataset as mentioned above...

def create_dataset(dataset, time_step):
    X_data = []
    Y_data = []
    for i in range(len(dataset)-time_step-1):
        X_data.append(dataset[i:(i+time_step), 0])
        Y_data.append(dataset[i+time_step, 0])
    return np.array(X_data), np.array(Y_data)

# %%
# Reshaping into tuples of the form with X=t, t+1,..t+99 and Y=t+100 for time_step=100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train.shape
# Out:
# (763, 100)

# %%
y_train.shape
# Out:
# (763,)

# %%
X_test.shape, y_test.shape
# Out:
# ((270, 100), (270,))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Step-7: Constructing Stacked LSTM model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
#Adding third LSTM layer and some dropouts

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
#Adding fourth LSTM layer and some dropouts

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
#Adding the output layer

regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to Training Data Set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 10s 183ms/step - loss: 0.0063
# Epoch 2/100
# 24/24 [==============================] - 5s 191ms/step - loss: 0.0019
# Epoch 3/100
# 24/24 [==============================] - 4s 172ms/step - loss: 0.0018
# Epoch 4/100
# 24/24 [==============================] - 4s 165ms/step - loss: 0.0015
# Epoch 5/100
# 24/24 [==============================] - 4s 171ms/step - loss: 0.0015
# Epoch 6/100
# 24/24 [==============================] - 4s 161ms/step - loss: 0.0013
# Epoch 7/100
# 24/24 [==============================] - 5s 210ms/step - loss: 0.0012
# Epoch 8/100
# 24/24 [==============================] - 6s 235ms/step - loss: 0.0012
# Epoch 9/100
# 24/24 [==============================] - 6s 254ms/step - loss: 0.0011
# Epoch 10/100
# 24/24 [==============================] - 5s 203ms/step - loss: 0.0011
# Epoch 11/100
# 24/24 [==============================] - 4s 188ms/step - loss: 9.9774e-04
# Epoch 12/100
# 24/24 [==============================] - 4s 186ms/step - loss: 0.0010
# Epoch 13/100
# 24/24 [==============================] - 5s 191ms/step - loss: 0.0010
# Epoch 14/100
# 24/24 [==============================] - 4s 186ms/step - loss: 9.3364e-04
# Epoch 15/100
# 24/24 [==============================] - 4s 151ms/step - loss: 9.4278e-04
# Epoch 16/100
# 24/24 [==============================] - 5s 202ms/step - loss: 8.8899e-04
# Epoch 17/100
# 24/24 [==============================] - 5s 187ms/step - loss: 8.5121e-04
# Epoch 18/100
# 24/24 [==============================] - 5s 210ms/step - loss: 8.5251e-04
# Epoch 19/100
# 24/24 [==============================] - 5s 196ms/step - loss: 8.0949e-04
# Epoch 20/100
# 24/24 [==============================] - 5s 203ms/step - loss: 8.1770e-04
# Epoch 21/100
# 24/24 [==============================] - 4s 176ms/step - loss: 7.5586e-04
# Epoch 22/100
# 24/24 [==============================] - 4s 167ms/step - loss: 8.2018e-04
# Epoch 23/100
# 24/24 [==============================] - 4s 187ms/step - loss: 7.2999e-04
# Epoch 24/100
# 24/24 [==============================] - 5s 174ms/step - loss: 8.7452e-04
# Epoch 25/100
# 24/24 [==============================] - 4s 187ms/step - loss: 7.5843e-04
# Epoch 26/100
# 24/24 [==============================] - 4s 177ms/step - loss: 7.0142e-04
# Epoch 27/100
# 24/24 [==============================] - 4s 171ms/step - loss: 7.2795e-04
# Epoch 28/100
# 24/24 [==============================] - 4s 169ms/step - loss: 6.5998e-04
# Epoch 29/100
# 24/24 [==============================] - 4s 165ms/step - loss: 6.4490e-04
# Epoch 30/100
# 24/24 [==============================] - 4s 177ms/step - loss: 6.4106e-04
# Epoch 31/100
# 24/24 [==============================] - 4s 164ms/step - loss: 6.2979e-04
# Epoch 32/100
# 24/24 [==============================] - 4s 181ms/step - loss: 6.1206e-04
# Epoch 33/100
# 24/24 [==============================] - 4s 186ms/step - loss: 6.0518e-04
# Epoch 34/100
# 24/24 [==============================] - 4s 182ms/step - loss: 6.1522e-04
# Epoch 35/100
# 24/24 [==============================] - 4s 176ms/step - loss: 5.4372e-04
# Epoch 36/100
# 24/24 [==============================] - 4s 176ms/step - loss: 5.9299e-04
# Epoch 37/100
# 24/24 [==============================] - 4s 171ms/step - loss: 5.6703e-04
# Epoch 38/100
# 24/24 [==============================] - 4s 177ms/step - loss: 6.1834e-04
# Epoch 39/100
# 24/24 [==============================] - 4s 167ms/step - loss: 5.2576e-04
# Epoch 40/100
# 24/24 [==============================] - 4s 175ms/step - loss: 4.9999e-04
# Epoch 41/100
# 24/24 [==============================] - 4s 164ms/step - loss: 5.0324e-04
# Epoch 42/100
# 24/24 [==============================] - 4s 156ms/step - loss: 5.0859e-04
# Epoch 43/100
# 24/24 [==============================] - 5s 192ms/step - loss: 5.2875e-04
# Epoch 44/100
# 24/24 [==============================] - 4s 180ms/step - loss: 4.7894e-04
# Epoch 45/100
# 24/24 [==============================] - 5s 216ms/step - loss: 4.8231e-04
# Epoch 46/100
# 24/24 [==============================] - 6s 236ms/step - loss: 4.6702e-04
# Epoch 47/100
# 24/24 [==============================] - 4s 177ms/step - loss: 4.7032e-04
# Epoch 48/100
# 24/24 [==============================] - 4s 175ms/step - loss: 4.7940e-04
# Epoch 49/100
# 24/24 [==============================] - 4s 167ms/step - loss: 4.4701e-04
# Epoch 50/100
# 24/24 [==============================] - 5s 207ms/step - loss: 4.5654e-04
# Epoch 51/100
# 24/24 [==============================] - 4s 177ms/step - loss: 4.7062e-04
# Epoch 52/100
# 24/24 [==============================] - 4s 176ms/step - loss: 4.9951e-04
# Epoch 53/100
# 24/24 [==============================] - 5s 212ms/step - loss: 4.4305e-04
# Epoch 54/100
# 24/24 [==============================] - 4s 182ms/step - loss: 4.5865e-04
# Epoch 55/100
# 24/24 [==============================] - 4s 169ms/step - loss: 4.1871e-04
# Epoch 56/100
# 24/24 [==============================] - 4s 174ms/step - loss: 4.0817e-04
# Epoch 57/100
# 24/24 [==============================] - 4s 177ms/step - loss: 4.0674e-04
# Epoch 58/100
# 24/24 [==============================] - 5s 191ms/step - loss: 3.7745e-04
# Epoch 59/100
# 24/24 [==============================] - 4s 190ms/step - loss: 4.0531e-04
# Epoch 60/100
# 24/24 [==============================] - 4s 182ms/step - loss: 3.9705e-04
# Epoch 61/100
# 24/24 [==============================] - 4s 175ms/step - loss: 4.1752e-04
# Epoch 62/100
# 24/24 [==============================] - 4s 185ms/step - loss: 3.5910e-04
# Epoch 63/100
# 24/24 [==============================] - 4s 163ms/step - loss: 3.9603e-04
# Epoch 64/100
# 24/24 [==============================] - 4s 169ms/step - loss: 3.6278e-04
# Epoch 65/100
# 24/24 [==============================] - 4s 179ms/step - loss: 4.0108e-04
# Epoch 66/100
# 24/24 [==============================] - 4s 176ms/step - loss: 3.8447e-04
# Epoch 67/100
# 24/24 [==============================] - 4s 171ms/step - loss: 3.3841e-04
# Epoch 68/100
# 24/24 [==============================] - 4s 171ms/step - loss: 3.5058e-04
# Epoch 69/100
# 24/24 [==============================] - 5s 189ms/step - loss: 3.3703e-04
# Epoch 70/100
# 24/24 [==============================] - 5s 192ms/step - loss: 3.2936e-04
# Epoch 71/100
# 24/24 [==============================] - 4s 187ms/step - loss: 3.8027e-04
# Epoch 72/100
# 24/24 [==============================] - 5s 189ms/step - loss: 3.6679e-04
# Epoch 73/100
# 24/24 [==============================] - 5s 192ms/step - loss: 3.3979e-04
# Epoch 74/100
# 24/24 [==============================] - 5s 189ms/step - loss: 3.3233e-04
# Epoch 75/100
# 24/24 [==============================] - 4s 177ms/step - loss: 3.1944e-04
# Epoch 76/100
# 24/24 [==============================] - 4s 172ms/step - loss: 3.3418e-04
# Epoch 77/100
# 24/24 [==============================] - 4s 179ms/step - loss: 3.0294e-04
# Epoch 78/100
# 24/24 [==============================] - 4s 170ms/step - loss: 3.1263e-04
# Epoch 79/100
# 24/24 [==============================] - 4s 158ms/step - loss: 2.9677e-04
# Epoch 80/100
# 24/24 [==============================] - 4s 179ms/step - loss: 2.9782e-04
# Epoch 81/100
# 24/24 [==============================] - 4s 174ms/step - loss: 2.9553e-04
# Epoch 82/100
# 24/24 [==============================] - 5s 189ms/step - loss: 2.8821e-04
# Epoch 83/100
# 24/24 [==============================] - 4s 173ms/step - loss: 2.7482e-04
# Epoch 84/100
# 24/24 [==============================] - 4s 182ms/step - loss: 3.1932e-04
# Epoch 85/100
# 24/24 [==============================] - 5s 189ms/step - loss: 2.8449e-04
# Epoch 86/100
# 24/24 [==============================] - 4s 185ms/step - loss: 2.9145e-04
# Epoch 87/100
# 24/24 [==============================] - 5s 191ms/step - loss: 2.8569e-04
# Epoch 88/100
# 24/24 [==============================] - 5s 188ms/step - loss: 2.7462e-04
# Epoch 89/100
# 24/24 [==============================] - 5s 189ms/step - loss: 2.9399e-04
# Epoch 90/100
# 24/24 [==============================] - 4s 184ms/step - loss: 2.8933e-04
# Epoch 91/100
# 24/24 [==============================] - 4s 150ms/step - loss: 3.1404e-04
# Epoch 92/100
# 24/24 [==============================] - 4s 176ms/step - loss: 2.5048e-04
# Epoch 93/100
# 24/24 [==============================] - 4s 174ms/step - loss: 2.8094e-04
# Epoch 94/100
# 24/24 [==============================] - 4s 186ms/step - loss: 2.8258e-04
# Epoch 95/100
# 24/24 [==============================] - 4s 177ms/step - loss: 2.5906e-04
# Epoch 96/100
# 24/24 [==============================] - 4s 183ms/step - loss: 2.5631e-04
# Epoch 97/100
# 24/24 [==============================] - 4s 181ms/step - loss: 2.5635e-04
# Epoch 98/100
# 24/24 [==============================] - 5s 190ms/step - loss: 2.8064e-04
# Epoch 99/100
# 24/24 [==============================] - 4s 178ms/step - loss: 2.7067e-04
# Epoch 100/100
# 24/24 [==============================] - 4s 183ms/step - loss: 2.5830e-04

# %%
# Constructing our stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1))) #Input layer with 50 neurons
model.add(LSTM(50, return_sequences=True)) # Hidden layers with 50 neurons
model.add(LSTM(50))
model.add(Dense(1))# Output Layer
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 100, 50)           10400
#
#  lstm_11 (LSTM)              (None, 100, 50)           20200
#
#  lstm_12 (LSTM)              (None, 50)                20200
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset_test = pd.read_csv(r"C:\Users\ushap\Downloads\NSE-TATAGLOBAL11.csv")
real_stock_price = dataset_test.iloc[:, 1:2].values

dataset_test
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...                    ...              ...
# 1230             1281419.0          2039.09
# 1231             1880046.0          3030.76
# 1232             3124853.0          4978.80
# 1233             2049580.0          3204.49
# 1234             1720413.0          2688.94
#
# [1235 rows x 8 columns]

# %%
real_stock_price
# Out:
# array([[208. ],
#        [217. ],
#        [223.5],
#        ...,
#        [156. ],
#        [155.7],
#        [157. ]])

# %%
dataset_train = pd.read_csv(r"C:\Users\ushap\Downloads\NSE-TATAGLOBAL11.csv")
predicted_stock_price = dataset_train.iloc[:, 1:2].values

dataset_train
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...                    ...              ...
# 1230             1281419.0          2039.09
# 1231             1880046.0          3030.76
# 1232             3124853.0          4978.80
# 1233             2049580.0          3204.49
# 1234             1720413.0          2688.94
#
# [1235 rows x 8 columns]

# %%
X_test = []
for i in range(60, 309):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# # Step-8: Evaluation of constructed LSTM Model.

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real TATAGLOBAL Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted TATAGLOBAL Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()

# %%
train_preds = minmax.inverse_transform(model.predict(X_train))
test_preds = minmax.inverse_transform(model.predict(X_test))
# Out:
# 24/24 [==============================] - 2s 50ms/step
# 8/8 [==============================] - 1s 31ms/step

# %%
import math
from sklearn.metrics import mean_squared_error

math.sqrt(mean_squared_error(y_train,train_preds))
# Out:
# 104.89265524960335

# %%
# Plot of Predictions on Closing Price made by our model on training dataset vs Actual Closing Price

plt.plot(minmax.inverse_transform(close_df))
plt.plot(trainPredictPlot)
plt.title("Variation of Predicted trained dataset(orange) and actual dataset(lightblue)", color="orange", fontsize=16, fontweight="bold")
plt.xlabel("Data Index Number")
plt.ylabel("Clossing price");

# %%
# Plot of Predictions on Closing Price made by our model on training dataset vs Actual Closing Price 
# vs Predictions on CLosing Price made by our model on test dataset

plt.plot(minmax.inverse_transform(close_df))
plt.plot(trainPredictPlot)
plt.title("Variation of Predicted tested dataset(green) and actual dataset(lightblue)", color="orange", fontsize=16, fontweight="bold")
plt.xlabel("Data Index Number")
plt.ylabel("Clossing price");
plt.plot(testPredictPlot)
plt.show()
